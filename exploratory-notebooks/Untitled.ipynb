# %%
import pickle

# %%
pickle.load(open('train_results_cum_tmp_13.pkl', 'rb'))
# Out:
# {10: [{'successes_argmax': [0.0,
#     0.05,
#     0.09,
#     0.175,
#     0.15,
#     0.215,
#     0.185,
#     0.235,
#     0.23,
#     0.235,
#     0.29],
#    'successes_sample': [0.0,
#     0.085,
#     0.135,
#     0.28,
#     0.4,
#     0.315,
#     0.445,
#     0.415,
#     0.505,
#     0.575,
#     0.615]},
#   {'successes_argmax': [0.0,
#     0.135,
#     0.185,
#     0.23,
#     0.255,
#     0.445,
#     0.495,
#     0.45,
#     0.49,
#     0.57,
#     0.59],
#    'successes_sample': [0.0,
#     0.025,
#     0.145,
#     0.235,
#     0.26,
#     0.305,
#     0.205,
#     0.24,
#     0.285,
#     0.205,
#     0.29]},
#   {'successes_argmax': [0.0,
#     0.07,
#     0.11,
#     0.18,
#     0.22,
#     0.3,
#     0.405,
#     0.39,
#     0.605,
#     0.595,
#     0.66],
#    'successes_sample': [0.0,
#     0.095,
#     0.195,
#     0.245,
#     0.4,
#     0.445,
#     0.405,
#     0.54,
#     0.575,
#     0.65,
#     0.56]},
#   {'successes_argmax': [0.0,
#     0.07,
# ...
